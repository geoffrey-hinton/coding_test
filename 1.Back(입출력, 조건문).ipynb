# %%
a,b = input("").split(" ")
print(a)
# Out:
# 1

# %%
a, b = input("").split(" ")
result = float(a) / float(b)
print(float(result))
# Out:
# 0.3333333333333333

# %%
a, b = input("").split(" ")
a_i = int(a)
b_i = int(b)

a_f = float(a)
b_f = float(b)

print(a_i + b_i)
print(a_i - b_i)
print(a_i * b_i)
print(int(a_i / b_i))
print(a_i % b_i)
# Out:
# 10
# 4
# 21
# 2
# 1

# %%
name = str(input(""))
print(name + "??!")
# Out:
# joonas??!

# %%
year = int(input(""))
print(year +)

# %%
a = int(input(""))
print(a - 543)
# Out:
# 543

# %%
# A, B, C 순서대로
# Line 1 : (a+b)%c, Line 2 : ((a%c) + (b%c))%c
# Line 3 : (a*b)%c, Line 3 : ((a%c) * (b%c))%c

a, b, c = map(int, input("").split())



print((a+b)%c)
print(((a%c) + (b%c))%c)
print((a*b)%c)
print(((a%c) * (b%c))%c)
# Out:
# 1
# 1
# 0
# 0

# %%
a, b = map(int, input("").split())
print(a)
print(b)
# Out:
# 472
# 385

# %%
a = input("")
b = input()

for i in reversed(b):
    print(int(i) * int(a))
print(int(a) * int(b))
# Out:
# 2360
# 3776
# 1416
# 181720

# %%
a, b, c = map(int, input().split(" "))

print(a + b + c)
# Out:
# 7931

# %%
a, b = map(int, input().split(" "))

if a > b:
    print(">")
elif a == b:
    print("==")
else:
    print("<")
# Out:
# <

# %%
a = int(input())

if 90 <= a <= 100:
    print("A")
elif 80 <= a < 90:
    print("B")
elif 70 <= a < 80:
    print("C")
elif 60 <= a < 70:
    print("D")
else:
    print("F")

# %%
a = int(input())

if a%4 == 0:
    if a%100 != 0 or a%400 == 0:
        print(1)
    else:
        print(0)
else:
    print(0)
# Out:
# 0

# %%
x = int(input())
y = int(input())

if x < 0:
    if y < 0:
        print(3)
    elif y > 0:
        print(2)
    else:
        pass
elif x > 0:
    if y > 0:
        print(1)
    elif y < 0:
        print(4)
    else:
        pass
else:
    pass
# Out:
# 4

# %%
a, b = map(int, input().split(" "))

temp_t = 0
h = 0
m = 0
if b < 45:
    if a == 0:
        h = 23
    else:
        h = a-1
    m = 60 + b - 45
else:
    h = a
    m = b-45

print(f"{h} {m}")
# Out:
# 22 55

# %%
# 2525번

# 현재 시간 = A(0 <= A <= 23), 분(0 <= B <= 59)
# 필요한 시간 = C(0 <= C <= 1000) *분단위

h, m = input().split(" ")
n_m = int(input())

# print(f"몫 : {n_m // 60}, 나머지 : {n_m % 60}")

result_h = int(h) + (n_m // 60)
result_m = int(m) + (n_m % 60)
if result_m == 60:
    result_h += 1
    result_m = 0
elif result_m > 60:
    result_h += 1
    result_m = result_m % 60

if result_h == 24:
    result_h = 0
elif result_h > 24:
    reslut_h = result_h % 24


print(f"{result_h} {result_m}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 6
#       1 # 2525번
#       2
#       3 # 현재 시간 = A(0 <= A <= 23), 분(0 <= B <= 59)
#       4 # 필요한 시간 = C(0 <= C <= 1000) *분단위
# ----> 6 h, m = input().split(" ")
#       7 n_m = int(input())
#       9 # print(f"몫 : {n_m // 60}, 나머지 : {n_m % 60}")
#
# ValueError: not enough values to unpack (expected 2, got 1)
